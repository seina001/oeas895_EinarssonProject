# %% [markdown]
# # Model development and analysis

# %% [markdown]
# This code is to develop a model using the Random Forest Regressor, SGDRegressor, RidgeCV, KNeighbors, MLPRegressor from scikit learn to predict the ratio of dinoflagellates/diatoms from environmental variables.

# %%
#Import packages needed to run code
import matplotlib.pyplot as plt #v3.1.3
import numpy as np #v1.18.1
import pandas as pd #v1.0.1
import seaborn as sns #v0.10.0
from pprint import pprint
#sklearn #v0.22.1
import sklearn
from sklearn.utils import shuffle 
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import RidgeCV
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# Data is imported and analyzed for outliers that may need to be duplicated to avoid overtraining. Alldata is the variable that includes predictor variables as well as the variable to be predicted. This includes temperature,salinity, chlorophyll, turbidity, wind direction, wind speed and the ratio of dinoflagellates/diatoms. Further on in the code the satalite data is imported and that is called DataSatalite. DataSatalite includes predictor variables (Temperature, salinity, wind direction, wind speed).
#
# To develop a model to predict the ratio from the satalite remote sensing data, only those variables that are included in both are used in developing the model.

# %%
#Import data file and sort based on ratio of dino/diatom. To choose outliers to duplicate.
infile = 'Alldata.csv'
Alldata = pd.read_csv(infile, sep = (','))
Alldata = Alldata.dropna()
#With everything
Alldata = Alldata[['Temp(C)','Salinity (PSU)','Chlorophyll_a(RFU)','Turbidity(RFU)','WDIR','WSPD','Ratio']]
Alldata = Alldata.sort_values(by = ['Ratio'],ascending=False)
Alldata.head()
# Out:
#     Temp(C)  Salinity (PSU)  Chlorophyll_a(RFU)  Turbidity(RFU)   WDIR   WSPD  \
# 0  6.057174            26.6        56040.223839       17.423257  339.5   9.50
# 2  5.733805            28.3           55.620772       16.165439   88.6  15.80
# 3  5.733710            28.7           43.946525       16.616810   84.6  16.48
# 4  5.887717            29.5           58.636307       15.506794  292.0   8.00
# 1  5.850963            27.8           69.064667       14.778982   86.0  15.30
#
#         Ratio
# 0  185.309955
# 2  165.614004
# 3   49.248689
# 4   12.985866
# 1   10.219107

# %%
#Plot histogram to decide if duplicates of outliers is needed
plt.hist(Alldata['Ratio'], color = 'blue', edgecolor = 'black',bins = int(180/5))
plt.ylabel('Samples',fontsize = 20)
plt.xlabel('Ratio (Dino\'s/Diatoms)',fontsize = 20)
plt.xticks(np.arange(0,186,5),fontsize = 12);
plt.yticks(fontsize = 12)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.savefig('Sample_histogram.png')

# %%
#Iterate through the dataset, if the ratio is above 5 (I chose 5 based on histogram above)
#then duplicate that row. This is increase the instances of the outliers in the data to make sure the model
#isn't over training on a certain range of data (in this case the ratio of dinos/diatoms)
Alldata_iter = Alldata
ADrow = []
for index,row in Alldata_iter.iterrows():
    if row['Ratio'] > 5:
        #row_list =[row['Temp(C)'], row['Salinity (PSU)'], row['Chlorophyll_a(RFU)'],row['Turbidity(RFU)'],row['WDIR'],row["WSPD"],row['Ratio']] 
        row_list = Alldata_iter.loc[index]
        ADrow.append(row_list)
        print(row['Ratio'])
Alldata = Alldata.append(ADrow)
#Print ratio measurements that were duplicated to prevent overtraining
# Out:
# 185.3099547511
# 165.6140035907
# 49.2486891386
# 12.9858664482
# 10.2191067494
# 7.2703881377999995
# 6.5502490477999995
# 5.734269370800001
# 5.4613417273
# 5.377659574500001

# %%
#Save input variables for model from the dataset as well as the predicted variable
X_alldata = Alldata[['Temp(C)','Salinity (PSU)','Chlorophyll_a(RFU)','Turbidity(RFU)','WDIR','WSPD']]
y_alldata = Alldata['Ratio']

X = X_alldata
y = y_alldata

print(np.shape(X))
print(np.shape(y))
# Out:
# (53, 6)
# (53,)

# %% [markdown]
# # RandomForestRegressor

# %%
#Use leave one out cross validation and iterate through a nested for loop to determine
#the best hyperperameter combination for the RandomForestRegressor model
res = []
results = []
#Initialize leave one out cross validation and the standard scaler for data normalization
loocv = LeaveOneOut()
scaler = StandardScaler()
#10-100 for n_estimators
for i in range(10,110,10):
    #2-10 for max tree depth (1 showed negative r2, not tested here to save computational time)
    for j in range(2,11,1):
        model = RandomForestRegressor(n_estimators = i, max_depth = j)
        #Run through leave one out cross validation and fit model each time
        for train_index, val_index in loocv.split(X):
            cv_train_x = X.iloc[train_index]
            scaler.fit(cv_train_x)
            cv_train_x = scaler.transform(cv_train_x)
            cv_val_x = X.iloc[val_index]
            cv_val_x = scaler.transform(cv_val_x)
            cv_train_y = y.iloc[train_index]
            cv_val_y = y.iloc[val_index]
            model.fit(cv_train_x, cv_train_y)
            pred = model.predict(cv_val_x)
            res.append([pred, cv_val_y])
        dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
        print("n_est = %s, max_depth = %s" %(i,j))
        #Calculate the r2 and rmse for each model run through leave one out cv
        rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
        rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
        print("R2 Predicted vs. Actual:",rsq)
        print("RMSE Predicted vs. Actual:",rmse)
        ijr2 = [i,j,rsq,rmse]
        results.append(ijr2)
        res = []
# Out:
# n_est = 10, max_depth = 2
# R2 Predicted vs. Actual: 0.6058784425439145
# RMSE Predicted vs. Actual: 447.752842409235
# n_est = 10, max_depth = 3
# R2 Predicted vs. Actual: 0.751951941713499
# RMSE Predicted vs. Actual: 278.67831060367007
# n_est = 10, max_depth = 4
# R2 Predicted vs. Actual: 0.510429212932947
# RMSE Predicted vs. Actual: 466.5855497080881
# n_est = 10, max_depth = 5
# R2 Predicted vs. Actual: 0.7707808345196324
# RMSE Predicted vs. Actual: 297.71536372280156
# n_est = 10, max_depth = 6
# R2 Predicted vs. Actual: 0.2696970406128769
# RMSE Predicted vs. Actual: 682.4453632981545
# n_est = 10, max_depth = 7
# R2 Predicted vs. Actual: 0.8102021921372865
# RMSE Predicted vs. Actual: 265.6677265148108
# n_est = 10, max_depth = 8
# R2 Predicted vs. Actual: 0.8010996362120862
# RMSE Predicted vs. Actual: 268.3038109081956
# n_est = 10, max_depth = 9
# R2 Predicted vs. Actual: 0.24932083593332055
# RMSE Predicted vs. Actual: 716.6287820791831
# n_est = 10, max_depth = 10
# R2 Predicted vs. Actual: 0.3667762065310255
# RMSE Predicted vs. Actual: 619.1347792380977
# n_est = 20, max_depth = 2
# R2 Predicted vs. Actual: 0.40124884310160325
# RMSE Predicted vs. Actual: 616.7158562143658
# n_est = 20, max_depth = 3
# R2 Predicted vs. Actual: 0.6467577857032765
# RMSE Predicted vs. Actual: 413.8915251508463
# n_est = 20, max_depth = 4
# R2 Predicted vs. Actual: 0.7965392202238858
# RMSE Predicted vs. Actual: 260.0861959656074
# n_est = 20, max_depth = 5
# R2 Predicted vs. Actual: 0.6248515977189559
# RMSE Predicted vs. Actual: 440.3374931146741
# n_est = 20, max_depth = 6
# R2 Predicted vs. Actual: 0.7834131171942635
# RMSE Predicted vs. Actual: 266.54194309480846
# n_est = 20, max_depth = 7
# R2 Predicted vs. Actual: 0.6684747782709463
# RMSE Predicted vs. Actual: 388.61781693213186
# n_est = 20, max_depth = 8
# R2 Predicted vs. Actual: 0.5604523263941368
# RMSE Predicted vs. Actual: 429.20706085219143
# n_est = 20, max_depth = 9
# R2 Predicted vs. Actual: 0.5609416176324655
# RMSE Predicted vs. Actual: 449.5921764414981
# n_est = 20, max_depth = 10
# R2 Predicted vs. Actual: 0.6755233936718343
# RMSE Predicted vs. Actual: 352.3308202346668
# n_est = 30, max_depth = 2
# R2 Predicted vs. Actual: 0.5312632246890778
# RMSE Predicted vs. Actual: 493.1943988503638
# n_est = 30, max_depth = 3
# R2 Predicted vs. Actual: 0.59199759582934
# RMSE Predicted vs. Actual: 480.1333645220433
# n_est = 30, max_depth = 4
# R2 Predicted vs. Actual: 0.6494124979377487
# RMSE Predicted vs. Actual: 385.06557970079564
# n_est = 30, max_depth = 5
# R2 Predicted vs. Actual: 0.5961090838384713
# RMSE Predicted vs. Actual: 442.4556986593343
# n_est = 30, max_depth = 6
# R2 Predicted vs. Actual: 0.7232454339076415
# RMSE Predicted vs. Actual: 350.3392549151487
# n_est = 30, max_depth = 7
# R2 Predicted vs. Actual: 0.6043711307778143
# RMSE Predicted vs. Actual: 438.7450677517282
# n_est = 30, max_depth = 8
# R2 Predicted vs. Actual: 0.6443461620122466
# RMSE Predicted vs. Actual: 350.59899378550864
# n_est = 30, max_depth = 9
# R2 Predicted vs. Actual: 0.677153091465805
# RMSE Predicted vs. Actual: 362.4892512453714
# n_est = 30, max_depth = 10
# R2 Predicted vs. Actual: 0.7095116138564976
# RMSE Predicted vs. Actual: 335.3215484171332
# n_est = 40, max_depth = 2
# R2 Predicted vs. Actual: 0.5807553439108835
# RMSE Predicted vs. Actual: 475.46019420131336
# n_est = 40, max_depth = 3
# R2 Predicted vs. Actual: 0.6518511355182337
# RMSE Predicted vs. Actual: 381.56625881524616
# n_est = 40, max_depth = 4
# R2 Predicted vs. Actual: 0.8148676577411957
# RMSE Predicted vs. Actual: 247.65686592948097
# n_est = 40, max_depth = 5
# R2 Predicted vs. Actual: 0.6489627497726169
# RMSE Predicted vs. Actual: 410.90513295360506
# n_est = 40, max_depth = 6
# R2 Predicted vs. Actual: 0.5372197791401947
# RMSE Predicted vs. Actual: 450.0271352027795
# n_est = 40, max_depth = 7
# R2 Predicted vs. Actual: 0.7865336242060712
# RMSE Predicted vs. Actual: 270.4885689035052
# n_est = 40, max_depth = 8
# R2 Predicted vs. Actual: 0.6045465682535701
# RMSE Predicted vs. Actual: 409.3770259560305
# n_est = 40, max_depth = 9
# R2 Predicted vs. Actual: 0.5987414322193545
# RMSE Predicted vs. Actual: 398.429693558554
# n_est = 40, max_depth = 10
# R2 Predicted vs. Actual: 0.6769299985813011
# RMSE Predicted vs. Actual: 386.3899529481427
# n_est = 50, max_depth = 2
# R2 Predicted vs. Actual: 0.45680611687319883
# RMSE Predicted vs. Actual: 561.5096174389798
# n_est = 50, max_depth = 3
# R2 Predicted vs. Actual: 0.7038506130532155
# RMSE Predicted vs. Actual: 349.2133783361745
# n_est = 50, max_depth = 4
# R2 Predicted vs. Actual: 0.7144624653814926
# RMSE Predicted vs. Actual: 316.8769326132654
# n_est = 50, max_depth = 5
# R2 Predicted vs. Actual: 0.5765410861215492
# RMSE Predicted vs. Actual: 441.17386627759004
# n_est = 50, max_depth = 6
# R2 Predicted vs. Actual: 0.6157972403497483
# RMSE Predicted vs. Actual: 398.1338651927514
# n_est = 50, max_depth = 7
# R2 Predicted vs. Actual: 0.7640276014863618
# RMSE Predicted vs. Actual: 290.2086781519288
# n_est = 50, max_depth = 8
# R2 Predicted vs. Actual: 0.64283798843062
# RMSE Predicted vs. Actual: 390.5456487242251
# n_est = 50, max_depth = 9
# R2 Predicted vs. Actual: 0.7683390119571178
# RMSE Predicted vs. Actual: 289.8492721277493
# n_est = 50, max_depth = 10
# R2 Predicted vs. Actual: 0.6950077846848365
# RMSE Predicted vs. Actual: 342.6589735933195
# n_est = 60, max_depth = 2
# R2 Predicted vs. Actual: 0.24961378629070452
# RMSE Predicted vs. Actual: 655.7120505487275
# n_est = 60, max_depth = 3
# R2 Predicted vs. Actual: 0.612521522496456
# RMSE Predicted vs. Actual: 391.6557377514569
# n_est = 60, max_depth = 4
# R2 Predicted vs. Actual: 0.6058979391580079
# RMSE Predicted vs. Actual: 394.9167409600719
# n_est = 60, max_depth = 5
# R2 Predicted vs. Actual: 0.6500273150290024
# RMSE Predicted vs. Actual: 385.56188210565426
# n_est = 60, max_depth = 6
# R2 Predicted vs. Actual: 0.7170458631366841
# RMSE Predicted vs. Actual: 323.8596119765654
# n_est = 60, max_depth = 7
# R2 Predicted vs. Actual: 0.7848735334991479
# RMSE Predicted vs. Actual: 260.4227852958795
# n_est = 60, max_depth = 8
# R2 Predicted vs. Actual: 0.6762890338116783
# RMSE Predicted vs. Actual: 372.7592299390761
# n_est = 60, max_depth = 9
# R2 Predicted vs. Actual: 0.4831983529522269
# RMSE Predicted vs. Actual: 456.6530615364461
# n_est = 60, max_depth = 10
# R2 Predicted vs. Actual: 0.6776790278130529
# RMSE Predicted vs. Actual: 349.0613982306604
# n_est = 70, max_depth = 2
# R2 Predicted vs. Actual: 0.2623283469306512
# RMSE Predicted vs. Actual: 688.0421794272215
# n_est = 70, max_depth = 3
# R2 Predicted vs. Actual: 0.7423814330925103
# RMSE Predicted vs. Actual: 305.8130311548087
# n_est = 70, max_depth = 4
# R2 Predicted vs. Actual: 0.4979889163515371
# RMSE Predicted vs. Actual: 474.4739906808897
# n_est = 70, max_depth = 5
# R2 Predicted vs. Actual: 0.5969856996216145
# RMSE Predicted vs. Actual: 395.85989345668014
# n_est = 70, max_depth = 6
# R2 Predicted vs. Actual: 0.7971108218876465
# RMSE Predicted vs. Actual: 245.94075335717682
# n_est = 70, max_depth = 7
# R2 Predicted vs. Actual: 0.5692312292197641
# RMSE Predicted vs. Actual: 433.03147925840204
# n_est = 70, max_depth = 8
# R2 Predicted vs. Actual: 0.7634584620766383
# RMSE Predicted vs. Actual: 283.8669145841369
# n_est = 70, max_depth = 9
# R2 Predicted vs. Actual: 0.6578845915462919
# RMSE Predicted vs. Actual: 400.5240903002645
# n_est = 70, max_depth = 10
# R2 Predicted vs. Actual: 0.7088416994018181
# RMSE Predicted vs. Actual: 335.0893644629908
# n_est = 80, max_depth = 2
# R2 Predicted vs. Actual: 0.49525317589153006
# RMSE Predicted vs. Actual: 526.7164755838779
# n_est = 80, max_depth = 3
# R2 Predicted vs. Actual: 0.6790460227661737
# RMSE Predicted vs. Actual: 368.61807260783763
# n_est = 80, max_depth = 4
# R2 Predicted vs. Actual: 0.6788490521301946
# RMSE Predicted vs. Actual: 346.6000836896013
# n_est = 80, max_depth = 5
# R2 Predicted vs. Actual: 0.734753745075134
# RMSE Predicted vs. Actual: 307.5658280198327
# n_est = 80, max_depth = 6
# R2 Predicted vs. Actual: 0.6663427513244482
# RMSE Predicted vs. Actual: 358.92449005031176
# n_est = 80, max_depth = 7
# R2 Predicted vs. Actual: 0.6611348536462297
# RMSE Predicted vs. Actual: 380.4207045348018
# n_est = 80, max_depth = 8
# R2 Predicted vs. Actual: 0.6836088037707113
# RMSE Predicted vs. Actual: 337.9774749039897
# n_est = 80, max_depth = 9
# R2 Predicted vs. Actual: 0.663058297776045
# RMSE Predicted vs. Actual: 374.81339206303693
# n_est = 80, max_depth = 10
# R2 Predicted vs. Actual: 0.5611369429284692
# RMSE Predicted vs. Actual: 447.00570816030245
# n_est = 90, max_depth = 2
# R2 Predicted vs. Actual: 0.4133364748622478
# RMSE Predicted vs. Actual: 573.0537647744522
# n_est = 90, max_depth = 3
# R2 Predicted vs. Actual: 0.6576631051096404
# RMSE Predicted vs. Actual: 366.4837527514058
# n_est = 90, max_depth = 4
# R2 Predicted vs. Actual: 0.6513121180067095
# RMSE Predicted vs. Actual: 368.0566519955463
# n_est = 90, max_depth = 5
# R2 Predicted vs. Actual: 0.6788999885480371
# RMSE Predicted vs. Actual: 349.1204319655176
# n_est = 90, max_depth = 6
# R2 Predicted vs. Actual: 0.6771934889895184
# RMSE Predicted vs. Actual: 357.45472422779494
# n_est = 90, max_depth = 7
# R2 Predicted vs. Actual: 0.5630891070288886
# RMSE Predicted vs. Actual: 419.5181223089762
# n_est = 90, max_depth = 8
# R2 Predicted vs. Actual: 0.7126387829034658
# RMSE Predicted vs. Actual: 312.9319942544736
# n_est = 90, max_depth = 9
# R2 Predicted vs. Actual: 0.7265615744158076
# RMSE Predicted vs. Actual: 310.15127753723766
# n_est = 90, max_depth = 10
# R2 Predicted vs. Actual: 0.6591214832974004
# RMSE Predicted vs. Actual: 370.2215209582579
# n_est = 100, max_depth = 2
# R2 Predicted vs. Actual: 0.36624388869091407
# RMSE Predicted vs. Actual: 578.0959486827287
# n_est = 100, max_depth = 3
# R2 Predicted vs. Actual: 0.7422830280610262
# RMSE Predicted vs. Actual: 296.0112900759313
# n_est = 100, max_depth = 4
# R2 Predicted vs. Actual: 0.701538329304497
# RMSE Predicted vs. Actual: 329.27326295946466
# n_est = 100, max_depth = 5
# R2 Predicted vs. Actual: 0.6452494944826803
# RMSE Predicted vs. Actual: 390.5925134146614
# n_est = 100, max_depth = 6
# R2 Predicted vs. Actual: 0.6588675754597859
# RMSE Predicted vs. Actual: 371.01052103272144
# n_est = 100, max_depth = 7
# R2 Predicted vs. Actual: 0.669104945090403
# RMSE Predicted vs. Actual: 368.7596323727581
# n_est = 100, max_depth = 8
# R2 Predicted vs. Actual: 0.7294562219288584
# RMSE Predicted vs. Actual: 306.76188398136566
# n_est = 100, max_depth = 9
# R2 Predicted vs. Actual: 0.5855342015750064
# RMSE Predicted vs. Actual: 405.4236028376603
# n_est = 100, max_depth = 10
# R2 Predicted vs. Actual: 0.6476005210479849
# RMSE Predicted vs. Actual: 372.70958318655397

# %%
#Make a heat map to visualize model results, to choose hypervariables
myarray = np.asarray(results)
data = pd.DataFrame({'n_estimators': myarray[:,0], 'max_depth': myarray[:,1], 'r2': myarray[:,2],'rmse': myarray[:,3]})
data_pivoted = data.pivot("n_estimators", "max_depth", "r2")
ax = sns.heatmap(data_pivoted,annot=True,cbar_kws={'label': 'R2 score'})
plt.show()

# %%
#Print table with r2 and rmse to observe results for each combination of hyperperameters for
#RandomTreeRegressor
print(data.iloc[data['r2'].idxmax()])
print(data.iloc[data['rmse'].idxmin()])
# Out:
# n_estimators     40.000000
# max_depth         4.000000
# r2                0.814868
# rmse            247.656866
# Name: 29, dtype: float64
# n_estimators     70.000000
# max_depth         6.000000
# r2                0.797111
# rmse            245.940753
# Name: 58, dtype: float64

# %% [markdown]
# Determine the best hyperperameter. In this case n_estimators = 10 and max_depth = 8

# %%
#Now test this model with these hyperperameter on the dataset using leave one out cross validation
#print out: r2 and rmse score for validation data 
X = X_alldata
y = y_alldata
#Initialize model using chosen hyperperameters
model = RandomForestRegressor(n_estimators = 10, max_depth = 8)
res=[]
#Again run leave one out cross validation is used and data is validated
for train_index, val_index in loocv.split(X):
    cv_train_x = X.iloc[train_index]
    scaler.fit(cv_train_x)
    cv_train_x = scaler.transform(cv_train_x)
    cv_val_x = X.iloc[val_index]
    cv_val_x = scaler.transform(cv_val_x)
    cv_train_y = y.iloc[train_index]
    cv_val_y = y.iloc[val_index]
    model.fit(cv_train_x, cv_train_y)
    pred = model.predict(cv_val_x)
    res.append([pred, cv_val_y])
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
print("n_estimators = %d, max_depth = %d" %(10,9))
rsq = r2_score(dTdf['Actual'],dTdf['Predicted'])
rmse = mean_squared_error(dTdf['Actual'],dTdf['Predicted'])
print("R2 Predicted vs. Actual:",rsq)
print("RMSE Predicted vs. Actual:",rmse)
#Plot the predicted vs actual test through each iteration of leave one out
#Run 1 to 1 dashed line to visualize over/under estimation
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
plt.plot(dTdf['Actual'],dTdf['Predicted'],'ro')
x = range(1,176,1)
plt.plot(x, x, linestyle='dashed')
plt.xlabel('Actual dino/diatom ratio')
plt.ylabel('Model predicted dino/diatom ratio')
plt.title('Actual vs Model Predicted dino/diatom ratio')
# Out:
# n_estimators = 10, max_depth = 9
# R2 Predicted vs. Actual: 0.8890310161943114
# RMSE Predicted vs. Actual: 233.5602475354515
# Text(0.5, 1.0, 'Actual vs Model Predicted dino/diatom ratio')

# %% [markdown]
# # Here develop a model, find best hyperperameters and calculate how well the model works on both the validation data and satalite data.
# Note: the satalite data doesn't have the same amount of input variables. Which is why the loop to find best hyperperameter is repeated. The satalite data does not have fluorometer data (fluorescence and turbidity).

# %%
#Read in data file with satalite measurements at stations that overlaped with my dataset
infile = 'Alldata_withSSTSSSsatallite.csv'
DataSatallite = pd.read_csv(infile, sep = (','))

# %%
#Now test this model with these hyperperameter on the dataset using leave one out cross validation
#print out: r2 and rmse score for validation data and satalite data 

#Initialize input/output variables for training dataset and satalite dataset
X_s = Alldata[['Temp(C)','Salinity (PSU)','WDIR','WSPD']]
y_s = Alldata['Ratio']

X_sata = DataSatallite[['SST','SSS','WDIR','WSPD']]
y_sata = DataSatallite['Ratio']

#Conduct same model estimation for best hyperparameter as done above
res = []
s_res = []
results = []
loocv = LeaveOneOut()
scaler = StandardScaler()
#10-100 for n_estimators
for i in range(10,110,10):
    #2-10 for max tree depth (1 showed negative r2, not tested here to save computational time)
    for j in range(2,11,1):
        model = RandomForestRegressor(n_estimators = i, max_depth = j)
        for train_index, val_index in loocv.split(X_s):
            cv_train_x = X_s.iloc[train_index]
            scaler.fit(cv_train_x)
            cv_train_x = scaler.transform(cv_train_x)
            cv_val_x = X_s.iloc[val_index]
            cv_val_x = scaler.transform(cv_val_x)
            cv_train_y = y_s.iloc[train_index]
            cv_val_y = y_s.iloc[val_index]
            cv_sat_x = scaler.transform(X_sata)
            model.fit(cv_train_x, cv_train_y)
            pred = model.predict(cv_val_x)
            pred_s = model.predict(cv_sat_x)
            res.append([pred, cv_val_y])
            rsq_sata = r2_score(pred_s,y_sata)
            rmse_sata = mean_squared_error(pred_s,y_sata)
            s_res.append([rsq_sata,rmse_sata])
        dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
        print("n_est = %s, max_depth = %s" %(i,j))
        rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
        rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
        print("R2/RMSE validation : ",rsq,"/",rmse)
        #Each iteration of leave one out, using that model predict ratio using input variables
        #from the satalite dataset. Then calculate R2 and RMSE and save for later analysis
        dTdf_sata = pd.DataFrame(s_res,columns=['R2','RMSE'])
        aversq_sata = np.mean(dTdf_sata['R2'])
        avermse_sata = np.mean(dTdf_sata['RMSE'])
        print("Average R2/RMSE of satalite data : ",aversq_sata,"/",avermse_sata)
        ijr2 = [i,j,rsq,rmse,aversq_sata,avermse_sata]
        results.append(ijr2)
        res = []
        s_res = []
# Out:
# n_est = 10, max_depth = 2
# R2/RMSE validation :  0.6001848232479884 / 600.539929599252
# Average R2/RMSE of satalite data :  0.8748369756851346 / 171.8831297870654
# n_est = 10, max_depth = 3
# R2/RMSE validation :  0.6712791094842361 / 432.7139723796487
# Average R2/RMSE of satalite data :  0.9326016049237481 / 111.64009957474262
# n_est = 10, max_depth = 4
# R2/RMSE validation :  0.7527725047281608 / 389.8977706402115
# Average R2/RMSE of satalite data :  0.9033812121548843 / 148.1166202929939
# n_est = 10, max_depth = 5
# R2/RMSE validation :  0.4760246216521624 / 486.51361018473284
# Average R2/RMSE of satalite data :  0.8492740931529359 / 185.63698322531044
# n_est = 10, max_depth = 6
# R2/RMSE validation :  0.7727406017591919 / 311.9830484763062
# Average R2/RMSE of satalite data :  0.8894774330474553 / 163.32855272777758
# n_est = 10, max_depth = 7
# R2/RMSE validation :  0.564295270418786 / 637.587152966283
# Average R2/RMSE of satalite data :  0.921865818309619 / 140.0573832968909
# n_est = 10, max_depth = 8
# R2/RMSE validation :  0.6348113456581268 / 487.9400306899858
# Average R2/RMSE of satalite data :  0.9128290281890243 / 147.9499777893749
# n_est = 10, max_depth = 9
# R2/RMSE validation :  0.47690921744734405 / 536.0457034806261
# Average R2/RMSE of satalite data :  0.8651699110391843 / 160.35501315220722
# n_est = 10, max_depth = 10
# R2/RMSE validation :  0.8334877008103896 / 239.7943221809697
# Average R2/RMSE of satalite data :  0.9043202872157077 / 149.6681572848824
# n_est = 20, max_depth = 2
# R2/RMSE validation :  0.4335875090973055 / 676.1819759662636
# Average R2/RMSE of satalite data :  0.9196604732278582 / 128.16783246787054
# n_est = 20, max_depth = 3
# R2/RMSE validation :  0.5306692571524045 / 552.8220220375147
# Average R2/RMSE of satalite data :  0.9229509113310546 / 127.25796941907026
# n_est = 20, max_depth = 4
# R2/RMSE validation :  0.4135543375588603 / 700.6504714075251
# Average R2/RMSE of satalite data :  0.8558667958256784 / 161.06138589025915
# n_est = 20, max_depth = 5
# R2/RMSE validation :  0.5824405300502055 / 456.9801098207578
# Average R2/RMSE of satalite data :  0.9241076162483423 / 127.22070699731673
# n_est = 20, max_depth = 6
# R2/RMSE validation :  0.5587212195275766 / 514.8944524863687
# Average R2/RMSE of satalite data :  0.9268344795706884 / 126.78709892225504
# n_est = 20, max_depth = 7
# R2/RMSE validation :  0.5297611528865847 / 489.85455438392546
# Average R2/RMSE of satalite data :  0.923539605620449 / 122.6906391565045
# n_est = 20, max_depth = 8
# R2/RMSE validation :  0.6280712254200884 / 436.62290153886363
# Average R2/RMSE of satalite data :  0.9324659546763691 / 118.94406332208314
# n_est = 20, max_depth = 9
# R2/RMSE validation :  0.603436751309679 / 484.90722669236436
# Average R2/RMSE of satalite data :  0.9178580085430669 / 136.903327692737
# n_est = 20, max_depth = 10
# R2/RMSE validation :  0.6074418444166356 / 472.96115728396364
# Average R2/RMSE of satalite data :  0.9278227726930025 / 119.88488645205132
# n_est = 30, max_depth = 2
# R2/RMSE validation :  0.47162361216327353 / 590.9094982207066
# Average R2/RMSE of satalite data :  0.9342711941751256 / 103.0007456962813
# n_est = 30, max_depth = 3
# R2/RMSE validation :  0.8192362863219549 / 261.75781023336464
# Average R2/RMSE of satalite data :  0.9409043552418289 / 100.52651345997904
# n_est = 30, max_depth = 4
# R2/RMSE validation :  0.7264107182792852 / 371.8391100276738
# Average R2/RMSE of satalite data :  0.9420198934630394 / 106.50882864567983
# n_est = 30, max_depth = 5
# R2/RMSE validation :  0.703234835482855 / 378.6084494074156
# Average R2/RMSE of satalite data :  0.9458657823181005 / 98.99994187500697
# n_est = 30, max_depth = 6
# R2/RMSE validation :  0.568674543621898 / 434.332388327438
# Average R2/RMSE of satalite data :  0.9370291732462741 / 109.0624684619292
# n_est = 30, max_depth = 7
# R2/RMSE validation :  0.6800911267000695 / 386.60329728360443
# Average R2/RMSE of satalite data :  0.9218698459548365 / 116.71410740278135
# n_est = 30, max_depth = 8
# R2/RMSE validation :  0.6971424986223698 / 346.1454719178863
# Average R2/RMSE of satalite data :  0.9152189241030102 / 132.05582166993176
# n_est = 30, max_depth = 9
# R2/RMSE validation :  0.5192210688861039 / 482.4361200607517
# Average R2/RMSE of satalite data :  0.9231927713526976 / 119.5062870710018
# n_est = 30, max_depth = 10
# R2/RMSE validation :  0.6066577161491581 / 472.1838611074861
# Average R2/RMSE of satalite data :  0.9192423010188172 / 131.62341216333988
# n_est = 40, max_depth = 2
# R2/RMSE validation :  0.3990919216500456 / 645.8215446625669
# Average R2/RMSE of satalite data :  0.928414197710404 / 110.53424462085057
# n_est = 40, max_depth = 3
# R2/RMSE validation :  0.6453168519570494 / 399.1578295271639
# Average R2/RMSE of satalite data :  0.9372992059358359 / 101.88567211237917
# n_est = 40, max_depth = 4
# R2/RMSE validation :  0.6477081347350465 / 467.37634158460895
# Average R2/RMSE of satalite data :  0.9333357434605396 / 119.18874398011198
# n_est = 40, max_depth = 5
# R2/RMSE validation :  0.589332403997439 / 465.2700946829804
# Average R2/RMSE of satalite data :  0.9307775325787242 / 111.75926645032096
# n_est = 40, max_depth = 6
# R2/RMSE validation :  0.6458215572654928 / 436.6724338235274
# Average R2/RMSE of satalite data :  0.9360031181993697 / 108.9709357772607
# n_est = 40, max_depth = 7
# R2/RMSE validation :  0.4496187557471868 / 596.2172115193314
# Average R2/RMSE of satalite data :  0.9153116039797659 / 125.39013239371616
# n_est = 40, max_depth = 8
# R2/RMSE validation :  0.5455784740745871 / 498.24462829221807
# Average R2/RMSE of satalite data :  0.933646714680138 / 111.59834919230113
# n_est = 40, max_depth = 9
# R2/RMSE validation :  0.6866890878034335 / 410.8759804911877
# Average R2/RMSE of satalite data :  0.9353101999868939 / 111.55256569135699
# n_est = 40, max_depth = 10
# R2/RMSE validation :  0.5770746591624367 / 478.22669243235873
# Average R2/RMSE of satalite data :  0.9065088239479737 / 115.65334001622756
# n_est = 50, max_depth = 2
# R2/RMSE validation :  0.4257918920635445 / 671.7256173591203
# Average R2/RMSE of satalite data :  0.9449788031308805 / 97.8388188019147
# n_est = 50, max_depth = 3
# R2/RMSE validation :  0.6087958255243241 / 461.01110498584944
# Average R2/RMSE of satalite data :  0.9336373063054153 / 108.02973904392367
# n_est = 50, max_depth = 4
# R2/RMSE validation :  0.44491890794039646 / 550.395912017006
# Average R2/RMSE of satalite data :  0.9281016285394038 / 107.09208578280166
# n_est = 50, max_depth = 5
# R2/RMSE validation :  0.6806736945532796 / 397.82426744967137
# Average R2/RMSE of satalite data :  0.9358447737970361 / 108.72518631039475
# n_est = 50, max_depth = 6
# R2/RMSE validation :  0.5894337919530198 / 513.6256211038187
# Average R2/RMSE of satalite data :  0.9298489917126462 / 118.99616090639651
# n_est = 50, max_depth = 7
# R2/RMSE validation :  0.5345915718867107 / 526.20056366724
# Average R2/RMSE of satalite data :  0.9196335005397623 / 128.1966678213214
# n_est = 50, max_depth = 8
# R2/RMSE validation :  0.6635339827990618 / 445.2338641316921
# Average R2/RMSE of satalite data :  0.9392232591810405 / 107.03389911383897
# n_est = 50, max_depth = 9
# R2/RMSE validation :  0.44789323845905704 / 580.977573471105
# Average R2/RMSE of satalite data :  0.9313358676331903 / 113.96969673917661
# n_est = 50, max_depth = 10
# R2/RMSE validation :  0.7428696847071765 / 340.58589242600414
# Average R2/RMSE of satalite data :  0.9407264023966049 / 105.00804652391479
# n_est = 60, max_depth = 2
# R2/RMSE validation :  0.0999457010414817 / 758.2562551280943
# Average R2/RMSE of satalite data :  0.9211450760714802 / 106.93279181074816
# n_est = 60, max_depth = 3
# R2/RMSE validation :  0.5826513792977515 / 445.3807539600985
# Average R2/RMSE of satalite data :  0.9375734387860322 / 98.2015360387757
# n_est = 60, max_depth = 4
# R2/RMSE validation :  0.5578806025456513 / 478.11503399165787
# Average R2/RMSE of satalite data :  0.9424549431830112 / 98.02013212249292
# n_est = 60, max_depth = 5
# R2/RMSE validation :  0.7073171928879431 / 372.1637869472404
# Average R2/RMSE of satalite data :  0.9425783668781771 / 102.84198181414666
# n_est = 60, max_depth = 6
# R2/RMSE validation :  0.635823840171753 / 427.96563057646796
# Average R2/RMSE of satalite data :  0.9368281635514399 / 105.84950949005733
# n_est = 60, max_depth = 7
# R2/RMSE validation :  0.5561089672684665 / 501.93928310248316
# Average R2/RMSE of satalite data :  0.9377911824168869 / 105.9535343553373
# n_est = 60, max_depth = 8
# R2/RMSE validation :  0.452390572248482 / 535.0559657295772
# Average R2/RMSE of satalite data :  0.923560856954585 / 104.54256607986704
# n_est = 60, max_depth = 9
# R2/RMSE validation :  0.6461637364635977 / 421.5189567117743
# Average R2/RMSE of satalite data :  0.9415045909022699 / 103.64869498349948
# n_est = 60, max_depth = 10
# R2/RMSE validation :  0.5657082220049412 / 498.3054877009007
# Average R2/RMSE of satalite data :  0.9282592618285316 / 115.01265618757583
# n_est = 70, max_depth = 2
# R2/RMSE validation :  0.47026995154323725 / 646.1911430481183
# Average R2/RMSE of satalite data :  0.9478712398218497 / 90.92071656558362
# n_est = 70, max_depth = 3
# R2/RMSE validation :  0.6070108201677771 / 441.00672470729137
# Average R2/RMSE of satalite data :  0.9334484461829504 / 106.05551039422829
# n_est = 70, max_depth = 4
# R2/RMSE validation :  0.4884701661799298 / 527.4742374397714
# Average R2/RMSE of satalite data :  0.9227050969545193 / 111.18358661186753
# n_est = 70, max_depth = 5
# R2/RMSE validation :  0.5141928822855437 / 557.5799460156045
# Average R2/RMSE of satalite data :  0.9278058464320204 / 118.18907475596244
# n_est = 70, max_depth = 6
# R2/RMSE validation :  0.6710847002510325 / 422.6236604972453
# Average R2/RMSE of satalite data :  0.9416771843636881 / 103.79597151015975
# n_est = 70, max_depth = 7
# R2/RMSE validation :  0.6096432948848021 / 445.7730844522135
# Average R2/RMSE of satalite data :  0.9423811202368514 / 100.22548713210936
# n_est = 70, max_depth = 8
# R2/RMSE validation :  0.5630543251008215 / 507.77337758589266
# Average R2/RMSE of satalite data :  0.9350385131777662 / 103.72124726211672
# n_est = 70, max_depth = 9
# R2/RMSE validation :  0.6582632234978211 / 403.4802502419803
# Average R2/RMSE of satalite data :  0.9382644038096007 / 105.18466802564689
# n_est = 70, max_depth = 10
# R2/RMSE validation :  0.5481382716609653 / 504.19530220720446
# Average R2/RMSE of satalite data :  0.9423067280974912 / 99.73368948767559
# n_est = 80, max_depth = 2
# R2/RMSE validation :  0.30366496855016545 / 705.2769366985357
# Average R2/RMSE of satalite data :  0.9412843244262872 / 94.85484525045347
# n_est = 80, max_depth = 3
# R2/RMSE validation :  0.6335866642426751 / 428.3142339818121
# Average R2/RMSE of satalite data :  0.9409316466233529 / 99.54018145853867
# n_est = 80, max_depth = 4
# R2/RMSE validation :  0.5490772395568071 / 490.3900019601447
# Average R2/RMSE of satalite data :  0.9376620502831285 / 104.93755275349673
# n_est = 80, max_depth = 5
# R2/RMSE validation :  0.5585957387180234 / 505.42719980706227
# Average R2/RMSE of satalite data :  0.9364573103840136 / 107.39332192391369
# n_est = 80, max_depth = 6
# R2/RMSE validation :  0.5488023149624581 / 531.0104005820228
# Average R2/RMSE of satalite data :  0.941632911200293 / 101.6738756919247
# n_est = 80, max_depth = 7
# R2/RMSE validation :  0.6839036942062411 / 377.46080716802174
# Average R2/RMSE of satalite data :  0.9442734880480496 / 98.12294798986089
# n_est = 80, max_depth = 8
# R2/RMSE validation :  0.6685628238628083 / 406.45760828787814
# Average R2/RMSE of satalite data :  0.9343013808985265 / 106.4138266075176
# n_est = 80, max_depth = 9
# R2/RMSE validation :  0.6460726968536052 / 429.8186372978229
# Average R2/RMSE of satalite data :  0.9397687787199591 / 105.78162174522566
# n_est = 80, max_depth = 10
# R2/RMSE validation :  0.5610271752637785 / 494.29896775384026
# Average R2/RMSE of satalite data :  0.9250259889648746 / 114.46348699908503
# n_est = 90, max_depth = 2
# R2/RMSE validation :  0.3887155639995389 / 644.1541530529474
# Average R2/RMSE of satalite data :  0.9474348533047277 / 87.47763268726224
# n_est = 90, max_depth = 3
# R2/RMSE validation :  0.6744713408590337 / 387.67236304847677
# Average R2/RMSE of satalite data :  0.9441795517560649 / 92.9253521171405
# n_est = 90, max_depth = 4
# R2/RMSE validation :  0.6365107255192783 / 408.5116371630103
# Average R2/RMSE of satalite data :  0.9387941431721761 / 100.07749992637284
# n_est = 90, max_depth = 5
# R2/RMSE validation :  0.652206812291559 / 386.4616137221114
# Average R2/RMSE of satalite data :  0.9419552503517032 / 102.24932836173255
# n_est = 90, max_depth = 6
# R2/RMSE validation :  0.6076500495056547 / 449.87158715871357
# Average R2/RMSE of satalite data :  0.9392042331875564 / 101.64384580231136
# n_est = 90, max_depth = 7
# R2/RMSE validation :  0.6368102665878335 / 430.33626067787753
# Average R2/RMSE of satalite data :  0.9409059219331389 / 101.38123860903704
# n_est = 90, max_depth = 8
# R2/RMSE validation :  0.567083535266341 / 460.3409149065685
# Average R2/RMSE of satalite data :  0.9276907628669082 / 112.5818213847509
# n_est = 90, max_depth = 9
# R2/RMSE validation :  0.6409951656104065 / 420.5911605105043
# Average R2/RMSE of satalite data :  0.9424747108685472 / 100.40728970301844
# n_est = 90, max_depth = 10
# R2/RMSE validation :  0.5350268418062905 / 500.26887919545936
# Average R2/RMSE of satalite data :  0.937699045385018 / 104.72000339338699
# n_est = 100, max_depth = 2
# R2/RMSE validation :  0.4345519900549286 / 645.9788128654355
# Average R2/RMSE of satalite data :  0.9481214717838066 / 90.29264237065195
# n_est = 100, max_depth = 3
# R2/RMSE validation :  0.5892181500530203 / 446.4613877897726
# Average R2/RMSE of satalite data :  0.9409416741674 / 97.68898273141299
# n_est = 100, max_depth = 4
# R2/RMSE validation :  0.5674301698756118 / 457.445127527289
# Average R2/RMSE of satalite data :  0.933205822049589 / 105.10648366606124
# n_est = 100, max_depth = 5
# R2/RMSE validation :  0.4787980286112965 / 528.560611914601
# Average R2/RMSE of satalite data :  0.933367558888021 / 104.89589318267443
# n_est = 100, max_depth = 6
# R2/RMSE validation :  0.6038350595323128 / 478.3124837753478
# Average R2/RMSE of satalite data :  0.9389124084315393 / 105.86600802752167
# n_est = 100, max_depth = 7
# R2/RMSE validation :  0.476875443308585 / 530.6340787212145
# Average R2/RMSE of satalite data :  0.9376938668544602 / 101.45946778211493
# n_est = 100, max_depth = 8
# R2/RMSE validation :  0.6472738066590239 / 432.43683312135187
# Average R2/RMSE of satalite data :  0.9391282361718573 / 107.69120487991087
# n_est = 100, max_depth = 9
# R2/RMSE validation :  0.6044188066373609 / 461.38884335602546
# Average R2/RMSE of satalite data :  0.9425008528839811 / 100.25870449657009
# n_est = 100, max_depth = 10
# R2/RMSE validation :  0.6507887998474564 / 411.3884707782524
# Average R2/RMSE of satalite data :  0.9419737824122115 / 102.07191664167888

# %%
#Make the results array into a pandas dataframe for table and plotting
myarray = np.asarray(results)
data = pd.DataFrame({'n_estimators': myarray[:,0], 'max_depth': myarray[:,1], 'r2': myarray[:,2],'rmse': myarray[:,3],'r2_sat_ave':myarray[:,4],'rmse_sat_ave':myarray[:,5]})
data
# Out:
#     n_estimators  max_depth        r2        rmse  r2_sat_ave  rmse_sat_ave
# 0           10.0        2.0  0.600185  600.539930    0.874837    171.883130
# 1           10.0        3.0  0.671279  432.713972    0.932602    111.640100
# 2           10.0        4.0  0.752773  389.897771    0.903381    148.116620
# 3           10.0        5.0  0.476025  486.513610    0.849274    185.636983
# 4           10.0        6.0  0.772741  311.983048    0.889477    163.328553
# ..           ...        ...       ...         ...         ...           ...
# 85         100.0        6.0  0.603835  478.312484    0.938912    105.866008
# 86         100.0        7.0  0.476875  530.634079    0.937694    101.459468
# 87         100.0        8.0  0.647274  432.436833    0.939128    107.691205
# 88         100.0        9.0  0.604419  461.388843    0.942501    100.258704
# 89         100.0       10.0  0.650789  411.388471    0.941974    102.071917
#
# [90 rows x 6 columns]

# %%
#Make a heat map to visualize model results, to choose hypervariables
data_pivoted = data.pivot("n_estimators", "max_depth", "r2")
ax = sns.heatmap(data_pivoted,annot=True,cbar_kws={'label': 'R2 score'})
plt.show()

# %%
#Print table with r2 and rmse to observe results for each combination of hyperperameters for
#RandomTreeRegressor
print(data.iloc[data['r2'].idxmax()])
print(data.iloc[data['rmse'].idxmin()])
# Out:
# n_estimators     10.000000
# max_depth        10.000000
# r2                0.833488
# rmse            239.794322
# r2_sat_ave        0.904320
# rmse_sat_ave    149.668157
# Name: 8, dtype: float64
# n_estimators     10.000000
# max_depth        10.000000
# r2                0.833488
# rmse            239.794322
# r2_sat_ave        0.904320
# rmse_sat_ave    149.668157
# Name: 8, dtype: float64

# %% [markdown]
# As seen above the best hyperparameters are 10 n_estimators and max depth =10.

# %%
#Now test this model with these hyperperameters on the dataset using leave one out cross validation
#print out: r2 and rmse score for validation data 
X_s = Alldata[['Temp(C)','Salinity (PSU)','WDIR','WSPD']]
y_s = Alldata['Ratio']
X_sata = DataSatallite[['SST','SSS','WDIR','WSPD']]
y_sata = DataSatallite['Ratio']
model = RandomForestRegressor(n_estimators = 10, max_depth = 10)
res=[]
s_res = []
sat_pred = []
for train_index, val_index in loocv.split(X_s):
    cv_train_x = X_s.iloc[train_index]
    scaler.fit(cv_train_x)
    cv_train_x = scaler.transform(cv_train_x)
    cv_val_x = X_s.iloc[val_index]
    cv_val_x = scaler.transform(cv_val_x)
    cv_train_y = y_s.iloc[train_index]
    cv_val_y = y_s.iloc[val_index]
    cv_sat_x = scaler.transform(X_sata)
    model.fit(cv_train_x, cv_train_y)
    pred = model.predict(cv_val_x)
    pred_s = model.predict(cv_sat_x)
    res.append([pred, cv_val_y])
    rsq_sata = r2_score(pred_s,y_sata)
    rmse_sata = mean_squared_error(pred_s,y_sata)
    s_res.append([rsq_sata,rmse_sata])
    sarray = y_sata
    sat_pred.append([[pred_s],[sarray]])
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
print("R2/RMSE validation : ",rsq,"/",rmse)
dTdf_sata = pd.DataFrame(s_res,columns=['R2','RMSE'])
aversq_sata = np.mean(dTdf_sata['R2'])
avermse_sata = np.mean(dTdf_sata['RMSE'])
print("Average R2/RMSE of satalite data : ",aversq_sata,"/",avermse_sata)
ijr2 = [i,j,rsq,rmse,aversq_sata,avermse_sata]
results.append(ijr2)

dTdf_pred_sat = pd.DataFrame(sat_pred,columns = ['Predicted','Actual'])
#plt.plot(dTdf_pred_sat['Actual'],dTdf_pred_sat['Predicted'],'ro')
Act_app = []
Pred_app = []
for i in range(0,len(dTdf_pred_sat['Predicted']),1):
    l = dTdf_pred_sat.iloc[i]
    plt.scatter(l['Actual'],l['Predicted'],color = 'k')
    for j in l['Actual']:
        Act_app.append(j)
    for k in l['Predicted']:
        Pred_app.append(k)
x = range(1,186,1)
plt.plot(x, x, linestyle='dashed')
plt.xlabel('Actual dino/diatom ratio')
plt.ylabel('Model predicted dino/diatom ratio')
plt.title('Actual vs Model Predicted dino/diatom ratio from satalite data')
# Out:
# R2/RMSE validation :  0.5955152429699454 / 433.4289095691938
# Average R2/RMSE of satalite data :  0.8994530036064284 / 149.89749144914006
# Text(0.5, 1.0, 'Actual vs Model Predicted dino/diatom ratio from satalite data')

# %%
#Use train test split to split training data to train/test model using hypervarialbes with
#chosen based on results above. This is to predict dino/diatom ratio using satalite data. 
#Without using leave one out, this is using train test split.
X_s = Alldata[['Temp(C)','Salinity (PSU)','WDIR','WSPD']]
y_s = Alldata['Ratio']
X_sata = DataSatallite[['SST','SSS','WDIR','WSPD']]
y_sata = DataSatallite['Ratio']

X_train,X_test,y_train,y_test = train_test_split(X_s,y_s,test_size=0.1,random_state=4)
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
X_sata = scaler.transform(X_sata)
model = RandomForestRegressor(n_estimators = 10, max_depth = 10)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_sat_pred = model.predict(X_sata)
m, b = np.polyfit(y_sata,y_sat_pred, 1)
fig1 = plt.plot(y_sata,y_sat_pred,'ro')
plt.title('Predicted vs. actual dino/diatom ratio using satalite data')
plt.xlabel('Actual dino/diatom ratio')
plt.ylabel('Predicted dino/diatom ratio')
plt.plot(y_sat_pred, m*y_sat_pred + b)
print('R2 for validation data')
print(r2_score(y_pred, y_test))
print('R2 for satalite data')
print(r2_score(y_sata,y_sat_pred))

from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(y_sata,y_sat_pred)
print('P-value:')
print("{:.8f}".format(p_value))
# Out:
# R2 for validation data
# 0.11118294885713709
# R2 for satalite data
# 0.9068866940630456
# P-value:
# 0.00000128

# %% [markdown]
# # Other models tested that didn't work out:
# - SGDRegressor
# - RidgeCV
# - KNeighbors

# %%
# SGDRegressor using leave one out
res = []
results = []
loocv = LeaveOneOut()
scaler = StandardScaler()
X = X_alldata
y = y_alldata
#10-100 for n_estimators
model = SGDRegressor()
for train_index, val_index in loocv.split(X):
    cv_train_x = X.iloc[train_index]
    scaler.fit(cv_train_x)
    cv_train_x = scaler.transform(cv_train_x)
    cv_val_x = X.iloc[val_index]
    cv_val_x = scaler.transform(cv_val_x)
    cv_train_y = y.iloc[train_index]
    cv_val_y = y.iloc[val_index]
    model.fit(cv_train_x, cv_train_y)
    pred = model.predict(cv_val_x)
    res.append([pred, cv_val_y])
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
print("R2 Predicted vs. Actual:",rsq)
print("RMSE Predicted vs. Actual:",rmse)
ijr2 = [i,j,rsq,rmse]
results.append(ijr2)
res = []
# Out:
# R2 Predicted vs. Actual: 0.19631344175829668
# RMSE Predicted vs. Actual: 1026.909317719199

# %%
#RidgeCV model testing using leave one out
res = []
results = []
loocv = LeaveOneOut()
scaler = StandardScaler()
X = X_alldata
y = y_alldata
#10-100 for n_estimators
model = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1])
for train_index, val_index in loocv.split(X):
    cv_train_x = X.iloc[train_index]
    scaler.fit(cv_train_x)
    cv_train_x = scaler.transform(cv_train_x)
    cv_val_x = X.iloc[val_index]
    cv_val_x = scaler.transform(cv_val_x)
    cv_train_y = y.iloc[train_index]
    cv_val_y = y.iloc[val_index]
    model.fit(cv_train_x, cv_train_y)
    pred = model.predict(cv_val_x)
    res.append([pred, cv_val_y])
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
print("R2 Predicted vs. Actual:",rsq)
print("RMSE Predicted vs. Actual:",rmse)
ijr2 = [i,j,rsq,rmse]
results.append(ijr2)
res = []
# Out:
# R2 Predicted vs. Actual: 0.1728406439817326
# RMSE Predicted vs. Actual: 1010.5193628601405

# %%
# KNeighbors
#run KNN with K neighbors ranging from 2-10, calculating 
#r2 and RMSE to find the best fit model
results = []
for j in range(2,11,1):
    model = KNeighborsRegressor(n_neighbors=j)
    for train_index, val_index in loocv.split(X):
        cv_train_x = X.iloc[train_index]
        scaler.fit(cv_train_x)
        cv_train_x = scaler.transform(cv_train_x)
        cv_val_x = X.iloc[val_index]
        cv_val_x = scaler.transform(cv_val_x)
        cv_train_y = y.iloc[train_index]
        cv_val_y = y.iloc[val_index]
        model.fit(cv_train_x, cv_train_y)
        pred = model.predict(cv_val_x)
        res.append([pred, cv_val_y])
    dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
    print("n_est = %s, max_depth = %s" %(i,j))
    rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
    rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
    print("R2 Predicted vs. Actual:",rsq)
    print("RMSE Predicted vs. Actual:",rmse)
    ijr2 = [j,rsq,rmse]
    results.append(ijr2)
    res = []
# Out:
# n_est = 52, max_depth = 2
# R2 Predicted vs. Actual: 0.4177971725302486
# RMSE Predicted vs. Actual: 578.5663097910751
# n_est = 52, max_depth = 3
# R2 Predicted vs. Actual: -0.12565171301105083
# RMSE Predicted vs. Actual: 1085.3488521151246
# n_est = 52, max_depth = 4
# R2 Predicted vs. Actual: -0.8471799581362673
# RMSE Predicted vs. Actual: 1389.6986065461074
# n_est = 52, max_depth = 5
# R2 Predicted vs. Actual: -1.6334133209774793
# RMSE Predicted vs. Actual: 1598.275905774487
# n_est = 52, max_depth = 6
# R2 Predicted vs. Actual: -2.3377384752921873
# RMSE Predicted vs. Actual: 1787.575014585449
# n_est = 52, max_depth = 7
# R2 Predicted vs. Actual: -2.6124508968181384
# RMSE Predicted vs. Actual: 1961.17892942293
# n_est = 52, max_depth = 8
# R2 Predicted vs. Actual: -3.2607189263795693
# RMSE Predicted vs. Actual: 1983.3062071618813
# n_est = 52, max_depth = 9
# R2 Predicted vs. Actual: -4.051061707934245
# RMSE Predicted vs. Actual: 1986.402160231905
# n_est = 52, max_depth = 10
# R2 Predicted vs. Actual: -5.062938195070875
# RMSE Predicted vs. Actual: 1990.3337545082995

# %%
#Make list into array to plot nicely, in order to look at all of the 
#results

myarray = np.asarray(results)

#make a dataframe with each column named for ploting
data = pd.DataFrame({'Kneighbors': myarray[:,0], 'R2': myarray[:,1], 'RMSE': myarray[:,2]})
data
# Out:
#    Kneighbors        R2         RMSE
# 0         2.0  0.417797   578.566310
# 1         3.0 -0.125652  1085.348852
# 2         4.0 -0.847180  1389.698607
# 3         5.0 -1.633413  1598.275906
# 4         6.0 -2.337738  1787.575015
# 5         7.0 -2.612451  1961.178929
# 6         8.0 -3.260719  1983.306207
# 7         9.0 -4.051062  1986.402160
# 8        10.0 -5.062938  1990.333755

# %% [markdown]
# # MLPRegressor model developed to predict ratio of dinoflagellates/diatoms

# %% [markdown]
# Only run the following model test of using the MLPRegressor if you have enough time. It will take awhile.

# %%
# MLPRegressor
X = X_alldata
y = y_alldata
# Create linear regression object
results_1 = []
layers = []
count_layer = 1
for x in range(10):
    while count_layer <11:
        layers.append(x+1)
        model = MLPRegressor(hidden_layer_sizes=layers,max_iter=1000,random_state=0)
        for train_index, val_index in loocv.split(X):
            cv_train_x = X.iloc[train_index]
            scaler.fit(cv_train_x)
            cv_train_x = scaler.transform(cv_train_x)
            cv_val_x = X.iloc[val_index]
            cv_val_x = scaler.transform(cv_val_x)
            cv_train_y = y.iloc[train_index]
            cv_val_y = y.iloc[val_index]
            model.fit(cv_train_x, cv_train_y)
            pred = model.predict(cv_val_x)
            res.append([pred, cv_val_y])
        dTdf_1 = pd.DataFrame(res,columns = ['Predicted','Actual'])
        print(layers)
        rsq = r2_score(dTdf_1['Predicted'], dTdf_1['Actual'])
        rmse = mean_squared_error(dTdf_1['Predicted'],dTdf_1['Actual'])
        print("R2 Predicted vs. Actual:",rsq)
        print("RMSE Predicted vs. Actual:",rmse)
        ijr2 = [x+1,count_layer,rsq,rmse]
        results_1.append(ijr2)
        res = []
        count_layer=count_layer+1
    count_layer=1
    layers=[]
# Out:
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [1]
# R2 Predicted vs. Actual: 0.24666824835727608
# RMSE Predicted vs. Actual: 839.4192856888707
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [1, 1]
# R2 Predicted vs. Actual: -28.38548870293503
# RMSE Predicted vs. Actual: 1803.0538769376883
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [1, 1, 1]
# R2 Predicted vs. Actual: -5.078364783356883
# RMSE Predicted vs. Actual: 2492.848008449349
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10]
# R2 Predicted vs. Actual: 0.9640148850634245
# RMSE Predicted vs. Actual: 76.68063093702615
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10]
# R2 Predicted vs. Actual: 0.5443499732561183
# RMSE Predicted vs. Actual: 1575.1228891943733
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10, 10]
# R2 Predicted vs. Actual: 0.996828009944196
# RMSE Predicted vs. Actual: 6.7389083557466725
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10, 10, 10]
# R2 Predicted vs. Actual: 0.9881747533609163
# RMSE Predicted vs. Actual: 24.645550498424072
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
# R2 Predicted vs. Actual: 0.9976233905957291
# RMSE Predicted vs. Actual: 5.06774911021132
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
import seaborn as sns
myarray_1 = np.asarray(results_1)
for i in range(0,len(myarray[:,2]),1):
    if myarray_1[i,2] < -9999:
        myarray_1[i,2] = '-9999'
plt.figure(figsize=(12, 8), edgecolor='w')
data_1 = pd.DataFrame({'nodes': myarray_1[:,0], 'layers': myarray_1[:,1], 'r2': myarray_1[:,2],'rmse': myarray_1[:,3]})
data_pivoted_1 = data_1.pivot("nodes", "layers", "r2")
ax = sns.heatmap(data_pivoted_1,vmin=0, vmax=1,annot=True,cbar_kws={'label': 'R2 score'},fmt="0.2f")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Layers',fontsize = 14)
plt.ylabel('Node size',fontsize = 14)
plt.title('R-square heatmap for each combination of hypervariables',fontsize = 16)
plt.savefig('MLPheatmap_1.png')

# %%
print(data_1.iloc[data_1['r2'].idxmax()])
print(data_1.iloc[data_1['rmse'].idxmin()])
# Out:
# nodes     6.000000
# layers    9.000000
# r2        0.997776
# rmse      4.667292
# Name: 58, dtype: float64
# nodes     6.000000
# layers    9.000000
# r2        0.997776
# rmse      4.667292
# Name: 58, dtype: float64

# %%
#Now test this model with these hyperperameter on the dataset using leave one out cross validation
#print out: r2 and rmse score for validation data 
X = X_alldata
y = y_alldata
#Initialize model using chosen hyperperameters
model = MLPRegressor(hidden_layer_sizes=(6,6,6,6,6,6,6,6,6),max_iter=1000,random_state=0)
res=[]
#Again leave one out cross validation is used and data is validated
for train_index, val_index in loocv.split(X):
    cv_train_x = X.iloc[train_index]
    scaler.fit(cv_train_x)
    cv_train_x = scaler.transform(cv_train_x)
    cv_val_x = X.iloc[val_index]
    cv_val_x = scaler.transform(cv_val_x)
    cv_train_y = y.iloc[train_index]
    cv_val_y = y.iloc[val_index]
    model.fit(cv_train_x, cv_train_y)
    pred = model.predict(cv_val_x)
    res.append([pred, cv_val_y])
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
print("layers = %d, nodes = %d" %(9,6))
rsq = r2_score(dTdf['Actual'],dTdf['Predicted'])
rmse = mean_squared_error(dTdf['Actual'],dTdf['Predicted'])
print("R2 Predicted vs. Actual:",rsq)
print("RMSE Predicted vs. Actual:",rmse)
#Plot the predicted vs actual test through each iteration of leave one out
#Run 1 to 1 dashed line to visualize over/under estimation
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
plt.plot(dTdf['Actual'],dTdf['Predicted'],'ro')
x = range(1,186,1)
plt.plot(x, x, linestyle='dashed')
plt.xlabel('Actual dino/diatom ratio')
plt.ylabel('Model predicted dino/diatom ratio')
plt.title('Actual vs Model Predicted dino/diatom ratio')
# Out:
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# layers = 9, nodes = 6
# R2 Predicted vs. Actual: 0.9977824795418675
# RMSE Predicted vs. Actual: 4.6672917904993625
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Text(0.5, 1.0, 'Actual vs Model Predicted dino/diatom ratio')

# %%
plt.figure(figsize=(12, 8), edgecolor='w')
plt.plot(dTdf['Actual'],dTdf['Predicted'],'ro')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
x = range(1,186,1)
plt.plot(x, x, linestyle='dashed')
plt.xlabel('Actual dino/diatom ratio',fontsize = 16)
plt.ylabel('Model predicted dino/diatom ratio',fontsize = 16)
plt.title('Actual vs Model Predicted dino/diatom ratio',fontsize = 18)
plt.savefig('ActualVModPred_MLP_1.png')

# %%
#Now test this model with these hyperperameter on the dataset using leave one out cross validation
#print out: r2 and rmse score for validation data and satalite data 

#Initialize input/output variables for training dataset and satalite dataset
X_s = Alldata[['Temp(C)','Salinity (PSU)','WDIR','WSPD']]
y_s = Alldata['Ratio']

X_sata = DataSatallite[['SST','SSS','WDIR','WSPD']]
y_sata = DataSatallite['Ratio']

#Conduct same model estimation for best hyperparameter as done above
res = []
s_res = []
sat_pred = []
loocv = LeaveOneOut()
scaler = StandardScaler()
results = []
layers = []
#choose number of layers and nodes to test model with
count_layer = 1
for x in range(1,10,1):
    while count_layer <11:
        layers.append(x+1)
        model = MLPRegressor(hidden_layer_sizes=layers,max_iter=1000,random_state=0)
        #Run leave one out cross validation for this MLPRegressor
        for train_index, val_index in loocv.split(X_s):
            cv_train_x = X_s.iloc[train_index]
            scaler.fit(cv_train_x)
            cv_train_x = scaler.transform(cv_train_x)
            cv_val_x = X_s.iloc[val_index]
            cv_val_x = scaler.transform(cv_val_x)
            cv_train_y = y_s.iloc[train_index]
            cv_val_y = y_s.iloc[val_index]
            cv_sat_x = scaler.transform(X_sata)
            model.fit(cv_train_x, cv_train_y)
            pred = model.predict(cv_val_x)
            pred_s = model.predict(cv_sat_x)
            res.append([pred, cv_val_y])
            rsq_sata = r2_score(pred_s,y_sata)
            rmse_sata = mean_squared_error(pred_s,y_sata)
            s_res.append([rsq_sata,rmse_sata])
            sarray = y_sata
            sat_pred.append([[pred_s],[sarray]])
        dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
        rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
        rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
        print(layers)
        print("R2/RMSE validation : ",rsq,"/",rmse)
        dTdf_sata = pd.DataFrame(s_res,columns=['R2','RMSE'])
        aversq_sata = np.mean(dTdf_sata['R2'])
        avermse_sata = np.mean(dTdf_sata['RMSE'])
        print("Average R2/RMSE of satalite data : ",aversq_sata,"/",avermse_sata)
        ijr2 = [x,count_layer,rsq,rmse,aversq_sata,avermse_sata]
        results.append(ijr2)
        count_layer = 1+count_layer
        res = []
        s_res = []
    count_layer = 1
    layers=[]
# Out:
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [2]
# R2/RMSE validation :  -24.212381645869176 / 1822.0397264762169
# Average R2/RMSE of satalite data :  -45.18100007529666 / 2213.9421518235963
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [2, 2]
# R2/RMSE validation :  -3.6699159571091604 / 1454.812725508199
# Average R2/RMSE of satalite data :  -47.41190866303043 / 2545.622114613708
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [2, 2, 2]
# R2/RMSE validation :  -1.4788497684864805 / 1377.7702154427602
# Average R2/RMSE of satalite data :  -8.678332443784399 / 1702.792124046026
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10]
# R2/RMSE validation :  0.9968586444817171 / 6.594942795122063
# Average R2/RMSE of satalite data :  -9.34492306883006 / 943.2418054916188
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10, 10]
# R2/RMSE validation :  0.9970595714215813 / 6.192191137390578
# Average R2/RMSE of satalite data :  -6581.882909274981 / 2382.331544710241
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10, 10, 10]
# R2/RMSE validation :  0.99811020517693 / 4.07925303406023
# Average R2/RMSE of satalite data :  0.6219419551217239 / 292.69779268691013
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
# R2/RMSE validation :  0.9977491881597531 / 4.790397031355099
# Average R2/RMSE of satalite data :  0.7871893542071071 / 249.1841050020906
# /home/denni/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
#Make a heat map to visualize model results, to choose hypervariables
import seaborn as sns
myarray = np.asarray(results)
for i in range(0,len(myarray[:,2]),1):
    if myarray[i,2] < -9999:
        myarray[i,2] = '-9999'
plt.figure(figsize=(12, 8), edgecolor='w')
lay = myarray[:,1]
data = pd.DataFrame({'nodes': myarray[:,0], 'layers': lay, 'r2': myarray[:,2],'rmse': myarray[:,3],'r2_satAVE': myarray[:,4],'r2_satRMSE':myarray[:,5]})
data_pivoted = data.pivot("nodes", "layers", "r2")
ax = sns.heatmap(data_pivoted,vmin=0, vmax=1,annot=True,cbar_kws={'label': 'R2 score'},fmt="0.2f")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Layers',fontsize = 14)
plt.ylabel('Node size',fontsize = 14)
plt.title('R-square heatmap for each combination of hypervariables',fontsize = 16)
plt.savefig('MLPheatmap_2.png')

# %%
#Print table with r2 and rmse to observe results for each combination of hyperperameters for
#MLPRegressor
print(data.iloc[data['r2'].idxmax()])
print(data.iloc[data['rmse'].idxmin()])
print(data.iloc[data['r2_satAVE'].idxmax])
print(data.iloc[data['r2_satRMSE'].idxmin])
# Out:
# nodes           9.000000
# layers          5.000000
# r2              0.999009
# rmse            2.081421
# r2_satAVE       0.834854
# r2_satRMSE    834.876207
# Name: 84, dtype: float64
# nodes           9.000000
# layers          5.000000
# r2              0.999009
# rmse            2.081421
# r2_satAVE       0.834854
# r2_satRMSE    834.876207
# Name: 84, dtype: float64
# nodes          6.000000
# layers         9.000000
# r2             0.998238
# rmse           3.726437
# r2_satAVE      0.973605
# r2_satRMSE    72.717220
# Name: 58, dtype: float64
# nodes          6.000000
# layers         9.000000
# r2             0.998238
# rmse           3.726437
# r2_satAVE      0.973605
# r2_satRMSE    72.717220
# Name: 58, dtype: float64

# %%
#Now test this model with these hyperperameters on the dataset using leave one out cross validation
#print out: r2 and rmse score for validation data 
X_s = Alldata[['Temp(C)','Salinity (PSU)','WDIR','WSPD']]
y_s = Alldata['Ratio']
X_sata = DataSatallite[['SST','SSS','WDIR','WSPD']]
y_sata = DataSatallite['Ratio']
model = MLPRegressor(hidden_layer_sizes=(9,9,9,9,9),max_iter=10000,random_state=0)
res=[]
s_res = []
sat_pred = []
for train_index, val_index in loocv.split(X_s):
    cv_train_x = X_s.iloc[train_index]
    scaler.fit(cv_train_x)
    cv_train_x = scaler.transform(cv_train_x)
    cv_val_x = X_s.iloc[val_index]
    cv_val_x = scaler.transform(cv_val_x)
    cv_train_y = y_s.iloc[train_index]
    cv_val_y = y_s.iloc[val_index]
    cv_sat_x = scaler.transform(X_sata)
    model.fit(cv_train_x, cv_train_y)
    pred = model.predict(cv_val_x)
    pred_s = model.predict(cv_sat_x)
    res.append([pred, cv_val_y])
    rsq_sata = r2_score(pred_s,y_sata)
    rmse_sata = mean_squared_error(pred_s,y_sata)
    s_res.append([rsq_sata,rmse_sata])
    sarray = y_sata
    sat_pred.append([[pred_s],[sarray]])
dTdf = pd.DataFrame(res,columns = ['Predicted','Actual'])
rsq = r2_score(dTdf['Predicted'], dTdf['Actual'])
rmse = mean_squared_error(dTdf['Predicted'],dTdf['Actual'])
print("R2/RMSE validation : ",rsq,"/",rmse)
dTdf_sata = pd.DataFrame(s_res,columns=['R2','RMSE'])
aversq_sata = np.mean(dTdf_sata['R2'])
avermse_sata = np.mean(dTdf_sata['RMSE'])
print("Average R2/RMSE of satalite data : ",aversq_sata,"/",avermse_sata)

dTdf_pred_sat = pd.DataFrame(sat_pred,columns = ['Predicted','Actual'])
#plt.plot(dTdf_pred_sat['Actual'],dTdf_pred_sat['Predicted'],'ro')
Act_app = []
Pred_app = []
for i in range(0,len(dTdf_pred_sat['Predicted']),1):
    l = dTdf_pred_sat.iloc[i]
    plt.scatter(l['Actual'],l['Predicted'],color = 'k')
    for j in l['Actual']:
        Act_app.append(j)
    for k in l['Predicted']:
        Pred_app.append(k)
x = range(1,186,1)
plt.plot(x, x, linestyle='dashed')
plt.xlabel('Actual dino/diatom ratio')
plt.ylabel('Model predicted dino/diatom ratio')
plt.title('Actual vs Model Predicted dino/diatom ratio from satalite data')
# Out:
# R2/RMSE validation :  0.9985219298893903 / 3.117266796803636
# Average R2/RMSE of satalite data :  0.6461082392632725 / 348.6026713946412
# Text(0.5, 1.0, 'Actual vs Model Predicted dino/diatom ratio from satalite data')

# %%
Act_app = []
Pred_app = []
plt.figure(figsize=(12, 8), edgecolor='w')
for i in range(0,len(dTdf_pred_sat['Predicted']),1):
    l = dTdf_pred_sat.iloc[i]
    plt.scatter(l['Actual'],l['Predicted'],color = 'k')
    for j in l['Actual']:
        Act_app.append(j)
    for k in l['Predicted']:
        Pred_app.append(k)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
x = range(1,186,1)
plt.plot(x, x, linestyle='dashed')
plt.xlabel('Actual dino/diatom ratio',fontsize = 16)
plt.ylabel('Model predicted dino/diatom ratio',fontsize = 16)
plt.title('Actual vs Model Predicted dino/diatom ratio',fontsize = 18)
plt.savefig('ActualVModPred_MLP_2.png')
